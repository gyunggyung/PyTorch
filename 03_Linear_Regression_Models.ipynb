# %%
import torch
from torch.autograd import Variable

from torch import nn

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
torch.manual_seed(3)

# %% [markdown]
# # make data

# %%
x_train = torch.Tensor([[1],[2],[3]])
y_train = torch.Tensor([[1],[2],[3]])

x, y = Variable(x_train), Variable(y_train)

plt.scatter(x.data.numpy(), y.data.numpy())
plt.show()

# %% [markdown]
# # Naive Model

# %% [markdown]
# ## Define Linear model

# %%
x, y
# Out:
# (Variable containing:
#   1
#   2
#   3
#  [torch.FloatTensor of size 3x1], Variable containing:
#   1
#   2
#   3
#  [torch.FloatTensor of size 3x1])

# %%
W = Variable(torch.rand(1,1))
W
# Out:
# Variable containing:
#  0.5508
# [torch.FloatTensor of size 1x1]

# %%
x.mm(W)
# Out:
# Variable containing:
#  0.5508
#  1.1016
#  1.6524
# [torch.FloatTensor of size 3x1]

# %% [markdown]
# ## Define cost function
#
# loss(x,y)=1/n∑|xi−yi|2loss(x,y)=1/n∑|xi−yi|2

# %%
cost_func = nn.MSELoss()

cost_func
# Out:
# MSELoss (
# )

# %% [markdown]
# ## Training Linear Regression

# %%
plt.ion()

lr = 0.01

for step in range(300):
    prediction = x.mm(W)
    cost = cost_func(prediction, y)
    gradient = (prediction-y).view(-1).dot(x.view(-1)) / len(x)
    W -= lr * gradient
    
    if step % 10 == 0:
        plt.cla()
        plt.scatter(x.data.numpy(), y.data.numpy())
        plt.plot(x.data.numpy(), prediction.data.numpy(), 'r-')
        plt.title('step %d, cost=%.4f, w=%.4f,grad=%.4f' %  (step,cost.data[0], W.data[0][0], gradient.data[0]), fontdict={'size': 20} )
        plt.show()
    
#     if step %10 == 0:
#         print(step, "going cost")
#         print(cost)
#         print((prediction-y).view(-1))
#         print((x.view(-1)))
#         print(gradient)
#         print(W)
plt.ioff()

# %%
x_test = Variable(torch.Tensor([[5]]))
y_test = x_test.mm(W)
y_test
# Out:
# Variable containing:
#  5.0000
# [torch.FloatTensor of size 1x1]

# %% [markdown]
# # w/ nn Module

# %% [markdown]
# ## Define Linear Model

# %%
model  = nn.Linear(1, 1, bias=True)

print(model)

model.weight, model.bias
# Out:
# Linear (1 -> 1)
# (Parameter containing:
#  -0.8586
#  [torch.FloatTensor of size 1x1], Parameter containing:
#   0.4163
#  [torch.FloatTensor of size 1])

# %%
cost_func = nn.MSELoss()

# %%
for i in model.parameters():
    print(i)
# Out:
# Parameter containing:
# -0.8586
# [torch.FloatTensor of size 1x1]
#
# Parameter containing:
#  0.4163
# [torch.FloatTensor of size 1]

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

# %% [markdown]
# ## Training w/ nn module

# %%
model(x)
# Out:
# Variable containing:
# -0.4423
# -1.3008
# -2.1594
# [torch.FloatTensor of size 3x1]

# %%
plt.ion()

for step in range(300):
    prediction = model(x)
    cost = cost_func(prediction, y)
    
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()
    
    if step % 10 == 0:
        plt.cla()
        plt.scatter(x.data.numpy(), y.data.numpy())
        plt.plot(x.data.numpy(), prediction.data.numpy(), 'b--')
        plt.title('cost=%.4f, w=%.4f, b=%.4f' % (cost.data[0],model.weight.data[0][0],model.bias.data[0]))
        plt.show()

plt.ioff()

# %%
x_test = Variable(torch.Tensor([[7]]))
y_test = model(x_test)

print('input : %.4f, output:%.4f' % (x_test.data[0][0], y_test.data[0][0]))
# Out:
# input : 7.0000, output:5.9583

# %%
for step in range(300):
    prediction = model(x)
    cost = cost_func(prediction, y)
    
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()

x_test = Variable(torch.Tensor([[7]]))
y_test = model(x_test)

print('input : %.4f, output:%.4f' % (x_test.data[0][0], y_test.data[0][0]))
# Out:
# input : 7.0000, output:6.9996

# %%
model.weight, model.bias
# Out:
# (Parameter containing:
#   0.9999
#  [torch.FloatTensor of size 1x1], Parameter containing:
#  1.00000e-04 *
#    1.7906
#  [torch.FloatTensor of size 1])

# %% [markdown]
# ###  Has "nn.MSELoss()"  Convex Cost Space?

# %%
W_val, cost_val = [], []

for i in range(-30, 51):
    W = i * 0.1
    model.weight.data.fill_(W)
    cost =  cost_func(model(x),y)
    
    W_val.append(W)
    cost_val.append(cost.data[0])

plt.plot(W_val, cost_val, 'ro')
plt.show()

# %% [markdown]
# # Multivariate Linear model

# %%
import numpy as np

# %% [markdown]
# ## make Data

# %%
xy = np.loadtxt('data-01-test-score.csv', delimiter=',', dtype=np.float32)
x_data = xy[:, 0:-1]
y_data = xy[:, [-1]]

print('shape: ', x_data.shape, '\nlength:', len(x_data), '\n', x_data )
print('shape: ', y_data.shape, '\nlength:', len(y_data), '\n', y_data )
# Out:
# shape:  (25, 3)
# length: 25
#  [[  73.   80.   75.]
#  [  93.   88.   93.]
#  [  89.   91.   90.]
#  [  96.   98.  100.]
#  [  73.   66.   70.]
#  [  53.   46.   55.]
#  [  69.   74.   77.]
#  [  47.   56.   60.]
#  [  87.   79.   90.]
#  [  79.   70.   88.]
#  [  69.   70.   73.]
#  [  70.   65.   74.]
#  [  93.   95.   91.]
#  [  79.   80.   73.]
#  [  70.   73.   78.]
#  [  93.   89.   96.]
#  [  78.   75.   68.]
#  [  81.   90.   93.]
#  [  88.   92.   86.]
#  [  78.   83.   77.]
#  [  82.   86.   90.]
#  [  86.   82.   89.]
#  [  78.   83.   85.]
#  [  76.   83.   71.]
#  [  96.   93.   95.]]
# shape:  (25, 1)
# length: 25
#  [[ 152.]
#  [ 185.]
#  [ 180.]
#  [ 196.]
#  [ 142.]
#  [ 101.]
#  [ 149.]
#  [ 115.]
#  [ 175.]
#  [ 164.]
#  [ 141.]
#  [ 141.]
#  [ 184.]
#  [ 152.]
#  [ 148.]
#  [ 192.]
#  [ 147.]
#  [ 183.]
#  [ 177.]
#  [ 159.]
#  [ 177.]
#  [ 175.]
#  [ 175.]
#  [ 149.]
#  [ 192.]]

# %%
x, y = Variable(torch.from_numpy(x_data)), Variable(torch.from_numpy(y_data))
x, y
# Out:
# (Variable containing:
#     73    80    75
#     93    88    93
#     89    91    90
#     96    98   100
#     73    66    70
#     53    46    55
#     69    74    77
#     47    56    60
#     87    79    90
#     79    70    88
#     69    70    73
#     70    65    74
#     93    95    91
#     79    80    73
#     70    73    78
#     93    89    96
#     78    75    68
#     81    90    93
#     88    92    86
#     78    83    77
#     82    86    90
#     86    82    89
#     78    83    85
#     76    83    71
#     96    93    95
#  [torch.FloatTensor of size 25x3], Variable containing:
#    152
#    185
#    180
#    196
#    142
#    101
#    149
#    115
#    175
#    164
#    141
#    141
#    184
#    152
#    148
#    192
#    147
#    183
#    177
#    159
#    177
#    175
#    175
#    149
#    192
#  [torch.FloatTensor of size 25x1])

# %% [markdown]
# ## make Model

# %%
mv_model = nn.Linear(3, 1, bias=True)

print(mv_model)
# Out:
# Linear (3 -> 1)

# %%
print('weigh : ', mv_model.weight)
print('bias   : ', mv_model.bias)
# Out:
# weigh :  Parameter containing:
#  0.0800  0.4537 -0.0727
# [torch.FloatTensor of size 1x3]
#
# bias   :  Parameter containing:
#  0.4576
# [torch.FloatTensor of size 1]

# %%
cost_func = nn.MSELoss()

optimizer = torch.optim.SGD(mv_model.parameters(), lr=1e-5)

# %% [markdown]
# ## Training Model

# %%
for step in range(2000):
    optimizer.zero_grad()
    
    prediction = mv_model(x)
    cost = cost_func(prediction, y)
    cost.backward()
    
    optimizer.step()
    
    if step % 50 == 0:
        print(step, "Cost: ", cost.data.numpy(), "\nPrediction:\n", prediction.data.t().numpy())
# Out:
# 0 Cost:  [ 15993.66210938]
# Prediction:
#  [[ 37.14835739  41.07077789  42.32987595  45.3395195   31.15942764
#    21.57414818  33.96046066  25.26793289  36.7249794   32.14643097
#    32.43621445  30.17488861  44.39228439  37.77391434  33.51408005
#    41.30649185  35.7885704   41.01784515  42.99427795  38.76438904
#    39.5009613   38.07882309  38.18299103  39.04036713  43.43421173]]
# 50 Cost:  [ 20.40331459]
# Prediction:
#  [[ 155.90655518  183.91719055  183.01861572  198.60231018  140.09570312
#    101.96617889  148.71470642  110.3808136   170.30203247  155.97410583
#    142.98558044  139.24357605  189.70205688  158.51609802  148.81689453
#    186.29193115  150.76269531  178.73524475  181.50273132  162.69216919
#    174.06936646  172.12194824  166.46203613  158.68077087  191.44090271]]
# 100 Cost:  [ 19.79937172]
# Prediction:
#  [[ 155.83552551  183.93902588  182.98152161  198.60321045  140.10491943
#    102.04921722  148.74671936  110.44519043  170.39778137  156.16366577
#    143.00595093  139.32681274  189.62332153  158.39875793  148.86964417
#    186.34356689  150.6340332   178.77493286  181.40458679  162.60023499
#    174.10758972  172.17590332  166.47761536  158.51467896  191.42724609]]
# 150 Cost:  [ 19.22133446]
# Prediction:
#  [[ 155.76617432  183.96031189  182.94525146  198.60412598  140.11376953
#    102.13034058  148.77815247  110.50839996  170.49131775  156.34902954
#    143.02590942  139.40815735  189.54626465  158.28392029  148.92132568
#    186.39402771  150.50805664  178.81394958  181.30859375  162.51036072
#    174.14511108  172.22862244  166.49298096  158.3522644   191.41381836]]
# 200 Cost:  [ 18.66807365]
# Prediction:
#  [[ 155.69841003  183.98100281  182.90975952  198.6050415   140.12229919
#    102.20959473  148.809021    110.57044983  170.58270264  156.53025818
#    143.04547119  139.4876709   189.47088623  158.17152405  148.9719696
#    186.4433136   150.38464355  178.85232544  181.21469116  162.42248535
#    174.18188477  172.28012085  166.50811768  158.19340515  191.40060425]]
#    175.03395081  173.40341187  166.8815918   154.67607117  191.07788086]]
# 1800 Cost:  [ 9.34075642]
# Prediction:
#  [[ 154.19429016  184.41346741  182.10714722  198.63795471  140.26011658
#    103.9718399   149.55345154  112.06252289  172.61442566  160.61695862
#    143.49891663  141.27090454  187.75221252  155.59584045  150.1547699
#    187.53968811  147.52531433  179.79985046  179.08692932  160.44067383
#    175.05397034  173.42778015  166.89105225  154.59817505  191.06980896]]
# 1850 Cost:  [ 9.20943928]
# Prediction:
#  [[ 154.1632843   184.42153931  182.09014893  198.63900757  140.26139832
#    104.00823212  149.57058716  112.09674835  172.65637207  160.70309448
#    143.5088501   141.30819702  187.71542358  155.54029846  150.18092346
#    187.56234741  147.46273804  179.82226562  179.04176331  160.39889526
#    175.07363892  173.45153809  166.90036011  154.52198792  191.06184387]]
# 1900 Cost:  [ 9.08364868]
# Prediction:
#  [[ 154.13304138  184.42939758  182.0735321   198.64006042  140.26255798
#    104.04376984  149.58744812  112.13038635  172.69737244  160.78733826
#    143.51860046  141.34465027  187.6794281   155.48594666  150.20657349
#    187.58448792  147.40144348  179.84437561  178.99757385  160.35804749
#    175.09294128  173.47477722  166.90956116  154.44749451  191.05403137]]
# 1950 Cost:  [ 8.96321964]
# Prediction:
#  [[ 154.10348511  184.43701172  182.05728149  198.64111328  140.26358032
#    104.07847595  149.60398865  112.16342163  172.73736572  160.86967468
#    143.52813721  141.38026428  187.6441803   155.43273926  150.23171997
#    187.60609436  147.34136963  179.86608887  178.95437622  160.31811523
#    175.11186218  173.49745178  166.91860962  154.37461853  191.04629517]]

# %%
mv_model.state_dict()
# Out:
# OrderedDict([('weight',
#                0.4947  0.6896  0.8311
#               [torch.FloatTensor of size 1x3]), ('bias',
#                0.4630
#               [torch.FloatTensor of size 1])])

# %% [markdown]
# ## test

# %%
print("Model score : ",mv_model(Variable(torch.Tensor([[73,80,75]]))).data.numpy())
print("Real score : 73,80,75,152")
# Out:
# Model score :  [[ 154.07466125]]
# Real score : 73,80,75,152

# %%
accuracy_list = []
for i,real_y in enumerate(y):
    accuracy = (mv_model((x[1])).data.numpy() - real_y.data.numpy())
    accuracy_list.append(np.absolute(accuracy))

for accuracy in accuracy_list:
    print(accuracy)

print("sum accuracy : ",sum(accuracy_list))
print("avg accuracy : ",sum(accuracy_list)/len(y))
# Out:
# [ 32.44438171]
# [ 0.55561829]
# [ 4.44438171]
# [ 11.55561829]
# [ 42.44438171]
# [ 83.44438171]
# [ 35.44438171]
# [ 69.44438171]
# [ 9.44438171]
# [ 20.44438171]
# [ 43.44438171]
# [ 43.44438171]
# [ 0.44438171]
# [ 32.44438171]
# [ 36.44438171]
# [ 7.55561829]
# [ 37.44438171]
# [ 1.44438171]
# [ 7.44438171]
# [ 25.44438171]
# [ 7.44438171]
# [ 9.44438171]
# [ 9.44438171]
# [ 35.44438171]
# [ 7.55561829]
# sum accuracy :  [ 614.5546875]
# avg accuracy :  [ 24.58218765]
